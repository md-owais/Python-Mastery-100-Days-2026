# %%
# implicit type conversion - auto type conversion
4 + 5.5
# Out:
# 9.5

# %%
5 + 6+7j
# Out:
# (11+7j)

# %%
4.5 + 5+5j
# Out:
# (9.5+5j)

# %%
# explicit - need to tell the program
int('45')
# Out:
# 45

# %%
float(4)
# Out:
# 4.0

# %%
str(5)
# Out:
# '5'

# %%
bool(1)
# Out:
# True

# %%
complex(4)
# Out:
# (4+0j)

# %%
list('Hello')
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
int("Kolkata")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-ba485ede04d5> in <module>
# ----> 1 int("Kolkata")
#
# ValueError: invalid literal for int() with base 10: 'Kolkata'

# %%
a = 4.5
int(a)
# Out:
# 4

# %%
a
# Out:
# 4.5

# %%
first_num = int(input("Enter the first number: "))
second_num = int(input("Enter the second number: "))
result = first_num + second_num
print(result)
# Out:
# Enter the first number: 10
# Enter the second number: 20
# 30
