# %% [markdown]
# # 16.	Write a program that will determine weather when the value of temperature and humidity is provided by the user.
#
# TEMPERATURE(C)      HUMIDITY(%)      WEATHER
#
#       >= 30                             >=90                Hot and Humid
#       >= 30                             < 90                 Hot
#       <30                                >= 90               Cool and Humid
#       <30                                 <90                 Cool

# %%
c = int(input("Enter Temperatue in Celsius: "))
h = int(input("Enter Humidity: "))
if c >= 30 and h >= 90:
    print('Hot and Humid')
elif c >= 30 and h < 90:
    print('Hot')
elif c < 30 and h >= 90:
    print('Cool and Humid')
else:
    print('Cool')
# Out:
# Enter Temperatue in Celsius: 30
# Enter Humidity: 90
# Hot and Humid
