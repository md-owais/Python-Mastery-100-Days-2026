# %%
input()
# Out:
# 56
# '56'

# %%
input("Tell me your name:")
# Out:
# Tell me your name:Owais
# 'Owais'

# %%
first_num = input("Enter the first number: ")
second_num = input("Enter the second number: ")
# Out:
# Enter the first number: 10
# Enter the second number: 20

# %%
print(first_num)
print(second_num)
# Out:
# 10
# 20

# %%
result = first_num + second_num
print(result) # User input always comes in string format
# Out:
# 1020

# %%
# type
type(result)
# Out:
# str

# %%
type(first_num)
# Out:
# str
