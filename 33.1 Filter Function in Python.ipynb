# %%
L = [1,2,3,4,5,6,7]
L
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
list(filter(lambda x:x>4, L))
# Out:
# [5, 6, 7]

# %%
fruits = ['Apple', 'Orange','Guava']
list(filter(lambda fruit:'e' in fruit, fruits))
# Out:
# ['Apple', 'Orange']
