# %%
# How to create own data type?
x = 5/6
x
# Out:
# 0.8333333333333334

# %%
class Fraction:
    
    def __init__(self, n, d):
        self.num = n
        self.den = d
x = Fraction(4,5)
print(type(x))
# Out:
# <class '__main__.Fraction'>

# %%
L = [1,2,3,x]
L
# Out:
# [1, 2, 3, <__main__.Fraction at 0x20be9ee6dc0>]

# %%
class Fraction:
    
    def __init__(self, n, d):
        self.num = n
        self.den = d
        
    def __str__(self):
        return "Hello"
    
x = Fraction(4,5)
print(x)
print(type(x))
# Out:
# Hello
# <class '__main__.Fraction'>

# %%
y = Fraction(5, 6)
print(y)
# Out:
# Hello

# %%
class Fraction:
    
    def __init__(self, n, d):
        self.num = n
        self.den = d
        
    def __str__(self):
        return "{}/{}".format(self.num,self.den)
    
x = Fraction(4,5)
print(x)
print(type(x))
# Out:
# 4/5
# <class '__main__.Fraction'>

# %%
y = Fraction(5,6)
print(y)
# Out:
# 5/6

# %%
print(x + y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f09a7b03ddbf> in <module>
# ----> 1 print(x + y)
#
# TypeError: unsupported operand type(s) for +: 'Fraction' and 'Fraction'

# %%
S1 = {1,2,3}
S2 = {4,5,6}
print(S1 + S2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-c19c008d2e01> in <module>
#       1 S1 = {1,2,3}
#       2 S2 = {4,5,6}
# ----> 3 print(S1 + S2)
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
class Fraction:
    
    def __init__(self, n, d):
        self.num = n
        self.den = d
        
    def __str__(self):
        return "{}/{}".format(self.num,self.den)
    
    def __add__(self, other):
        temp_num = self.num * other.den + other.num * self.den
        temp_den = self.den * other.den
        
        return "{}/{}".format(temp_num, temp_den)
    
x = Fraction(4,5)
y = Fraction(5,6)
print(x)
print(y)
# Out:
# 4/5
# 5/6

# %%
print(x + y)
# Out:
# 49/30

# %%
print(x - y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-cf151286cbb1> in <module>
# ----> 1 print(x - y)
#
# TypeError: unsupported operand type(s) for -: 'Fraction' and 'Fraction'

# %%
class Fraction:
    
    def __init__(self, n, d):
        self.num = n
        self.den = d
        
    def __str__(self):
        return "{}/{}".format(self.num,self.den)
    
    def __add__(self, other):
        temp_num = self.num * other.den + other.num * self.den
        temp_den = self.den * other.den
        
        return "{}/{}".format(temp_num, temp_den)
    
    def __sub__(self, other):
        temp_num = self.num * other.den - other.num * self.den
        temp_den = self.den * other.den
        
        return "{}/{}".format(temp_num, temp_den)
    
x = Fraction(4,5)
y = Fraction(5,6)
print(x)
print(y)
# Out:
# 4/5
# 5/6

# %%
print(x - y)
# Out:
# -1/30

# %%
class Fraction:
    
    def __init__(self, n, d):
        self.num = n
        self.den = d
        
    def __str__(self):
        return "{}/{}".format(self.num,self.den)
    
    def __add__(self, other):
        temp_num = self.num * other.den + other.num * self.den
        temp_den = self.den * other.den
        
        return "{}/{}".format(temp_num, temp_den)
    
    def __sub__(self, other):
        temp_num = self.num * other.den - other.num * self.den
        temp_den = self.den * other.den
        
        return "{}/{}".format(temp_num, temp_den)
    
    def __mul__(self, other):
        temp_num = self.num * other.den
        temp_den = self.den * other.num
        
        return "{}/{}".format(temp_num, temp_den)
    
x = Fraction(4,5)
y = Fraction(5,6)
print(x)
print(y)
# Out:
# 4/5
# 5/6

# %%
print(x * y)
# Out:
# 24/25
