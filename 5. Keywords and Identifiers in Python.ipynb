# %% [markdown]
# # Keywords
# . Python is a case sensitve programming language
#
# In Programming, a keyword is a word that is reversed by a program because the word has a special meaning. Kewords can be commands or parameters. Every programming language has a set of keywords that cannot be used as variable names

# %%
# Python has 33 keywords
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Identifier
# A Python identifier is a name used to identify a variable, function, class, module or other object
#
# Rules for setting Identifier
# 1. can only start with alphabet or _
# 2. Followes by 0 or more letter, _ and digits
# 3. kewords cannot be used as an identifiers

# %%
Name = 'Owais'
print(Name)
# Out:
# Owais

# %%
_ = 'Owais'
print(_)
# Out:
# Owais

# %%
2 = 'Owais'
print(2)
# Out:
#   File "<ipython-input-5-fcc30543b617>", line 1
#     2 = 'Owais'
#     ^
# SyntaxError: cannot assign to literal

# %%
# = 'Owais'
print(#)
# Out:
#   File "<ipython-input-6-814eab2d24d0>", line 2
#     print(#)
#             ^
# SyntaxError: unexpected EOF while parsing

# %%
name1 = 'Owais'
print(name1)
# Out:
# Owais

# %%
1name = 'Owais'
print(1name)
# Out:
#   File "<ipython-input-8-468734c62e54>", line 1
#     1name = 'Owais'
#      ^
# SyntaxError: invalid syntax

# %%
first_name = 'Owais'
print(first_name)
# Out:
# Owais

# %%
__ = 'Owais'
print(__)
# Out:
# Owais

# %%
False = 'Owais'
print(False)
# Out:
#   File "<ipython-input-12-45fe5555d8f0>", line 1
#     False = 'Owais'
#     ^
# SyntaxError: cannot assign to False
