# %% [markdown]
# # Mutability refers to the ability to change or edit data in it's memory location
#
# Mutability depends on the data type

# %% [raw]
# Immutable Data Types:
# 1. Strings
# 2. int
# 3. Float
# 4. Bool
# 5. Complex
# 6. Tuple
#
# Mutable Data Types:
# 1. List
# 2. Dictionary
# 3. Sets

# %%
a = 'Hello'
id(a)
# Out:
# 2714100938416

# %%
a = a + "world"
a
# Out:
# 'Helloworld'

# %%
id(a)
# Out:
# 2714101002096

# %%
T = (1,2,3)
id(T)
# Out:
# 2714101050432

# %%
T = T + (5,6)
T
# Out:
# (1, 2, 3, 5, 6, 5, 6)

# %%
id(T)
# Out:
# 2714100502688

# %%
L = [1,2,3]
L
# Out:
# [1, 2, 3]

# %%
id(L)
# Out:
# 2714100526528

# %%
L.append(4)

# %%
L
# Out:
# [1, 2, 3, 4]

# %%
id(L)
# Out:
# 2714100526528

# %%
# Mutability Side effects -> It changes original as well
L = [1,2,3]
L1 = L
L1
# Out:
# [1, 2, 3]

# %%
id(L1)
# Out:
# 2714100710464

# %%
L1.append(4)
L1
# Out:
# [1, 2, 3, 4]

# %%
id(L1)
# Out:
# 2714100710464

# %%
id(L)
# Out:
# 2714100710464

# %%
L
# Out:
# [1, 2, 3, 4]

# %%
# To prevent this -> cloning
L
# Out:
# [1, 2, 3, 4]

# %%
L1 = L[:] # syntax - b = a[:] - copying the value with different memory address
id(L)
# Out:
# 2714100710464

# %%
id(L1)
# Out:
# 2714100711040

# %%
L1.append(5)
L1
# Out:
# [1, 2, 3, 4, 5]

# %%
id(L1)
# Out:
# 2714100711040

# %%
id(L)
# Out:
# 2714100710464

# %%
a = (1,2,3,[4,5])
a
# Out:
# (1, 2, 3, [4, 5])

# %%
a[-1][-1] = 500
a
# Out:
# (1, 2, 3, [4, 500])

# %%
a = [1,2,3,(4,5)]
a[-1][-1] = 500
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-5bcfa40327b1> in <module>
#       1 a = [1,2,3,(4,5)]
# ----> 2 a[-1][-1] = 500
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = [1,2]
b = [3,4]
c = (a,b)

# %%
c
# Out:
# ([1, 2], [3, 4])

# %%
id(a)
# Out:
# 2714101110656

# %%
id(b)
# Out:
# 2714100694720

# %%
id(c)
# Out:
# 2714099736128

# %%
c[0][0] = 100
c
# Out:
# ([100, 2], [3, 4])

# %%
id(a)
# Out:
# 2714101110656

# %%
id(c)
# Out:
# 2714099736128

# %%
c
# Out:
# ([100, 2], [3, 4])

# %%
L = [1,2,3]
id(L)
# Out:
# 2714100710336

# %%
L = L + [4,5]
L
# Out:
# [1, 2, 3, 4, 5]

# %%
id(L)
# Out:
# 2714101077632

# %%
c
# Out:
# ([100, 2], [3, 4])

# %%
c[0] = c[0] + [5,6]
c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-620f9ebac553> in <module>
# ----> 1 c[0] = c[0] + [5,6]
#       2 c
#
# TypeError: 'tuple' object does not support item assignment

# %%
c
# Out:
# ([100, 2], [3, 4])

# %%
a
# Out:
# [100, 2]

# %%
a = a + [5,6]
a
# Out:
# [100, 2, 5, 6]

# %%
c
# Out:
# ([100, 2], [3, 4])
