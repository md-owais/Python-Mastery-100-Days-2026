# %% [markdown]
# # Variable and Memory References

# %%
a # python calls vriable as name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a = 4 # Call By Object Reference
id(a)
# Out:
# 140712181573520

# %%
hex(140712181573520)
# Out:
# '0x7ffa1b992790'

# %%
id(4)
# Out:
# 140712181573520

# %%
# Aliasing
a = 5
b = a

# %%
id(a)
# Out:
# 140712181573552

# %%
id(b)
# Out:
# 140712181573552

# %%
c = b
id(c)
# Out:
# 140712181573552

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
b
# Out:
# 5

# %%
del b

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-89e6c98d9288> in <module>
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
c
# Out:
# 5

# %%
a = 5
b = a

# %%
a = 6

# %%
b
# Out:
# 5

# %%
import sys
a = 'corona'
b = a
c = b

# %%
id(a)
id(b)
id(c)
# Out:
# 1475760186672

# %%
b
# Out:
# 'corona'

# %%
c
# Out:
# 'corona'

# %%
sys.getrefcount(a)
# Out:
# 17

# %%
a = 'environment'
b = a
c = b
sys.getrefcount(a)
# Out:
# 29
