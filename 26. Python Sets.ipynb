# %%
# Sets do not allow duplicates
# Sets have no indexing/slicing
# Sets don't allow mutable data types
# Sets itself is a mutable data type

# %%
S1 = {}
S1
# Out:
# {}

# %%
type(S1)
# Out:
# dict

# %%
S1 = set()

# %%
S1
# Out:
# set()

# %%
type(S1)
# Out:
# set

# %%
S1 = {1,2,3,4,5}
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
S2 = {'Hello',4,5,True}
S2
# Out:
# {4, 5, 'Hello', True}

# %%
S3 = {1,1,2,2,3,3}
S3
# Out:
# {1, 2, 3}

# %%
S4 = {[1,2,3],"Hello"}
S4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-bd9f203fe8df> in <module>
# ----> 1 S4 = {[1,2,3],"Hello"}
#       2 S4
#
# TypeError: unhashable type: 'list'

# %%
S4 = {(1,2,3),"Hello"} # order dosen't follow as indexing is not there
S4 # using Hashing
# Out:
# {(1, 2, 3), 'Hello'}

# %%
S5 = {{1},{2}}
S5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-fb795a451c89> in <module>
# ----> 1 S5 = {{1},{2}}
#       2 S5
#
# TypeError: unhashable type: 'set'

# %%
# Accessing items
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
S1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-d41740c20646> in <module>
# ----> 1 S1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
S1[-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-a52438ed66ec> in <module>
# ----> 1 S1[-1]
#
# TypeError: 'set' object is not subscriptable

# %%
S1[0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-de0ad38825f3> in <module>
# ----> 1 S1[0:3]
#
# TypeError: 'set' object is not subscriptable

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
id(S1)
# Out:
# 1412341468512

# %%
L = list(S1)
L
# Out:
# [1, 2, 3, 4, 5]

# %%
L[0] = 100
L
# Out:
# [100, 2, 3, 4, 5]

# %%
S1 = set(L)
S1
# Out:
# {2, 3, 4, 5, 100}

# %%
id(S1)
# Out:
# 1412342068160

# %%
# Add
S1
# Out:
# {2, 3, 4, 5, 100}

# %%
S1.add(6)
S1
# Out:
# {2, 3, 4, 5, 6, 100}

# %%
S1.add(7)
S1
# Out:
# {2, 3, 4, 5, 6, 7, 100}

# %%
id(S1)
# Out:
# 1412342068160

# %%
# Delete - del, remove, pop
del S2

# %%
S2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-56737722f54b> in <module>
# ----> 1 S2
#
# NameError: name 'S2' is not defined

# %%
del S1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-c7b002eddb68> in <module>
# ----> 1 del S1[0]
#
# TypeError: 'set' object doesn't support item deletion

# %%
S1.remove(100)
S1
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
S1.pop()
# Out:
# 2

# %%
S1
# Out:
# {3, 4, 5, 6, 7}

# %%
# Set Operation
S1 = {1,2,3,4,5}
S2 = {3,4,5,6,7}

S1 + S2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-a29215119ad7> in <module>
#       3 S2 = {3,4,5,6,7}
#       4
# ----> 5 S1 + S2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
S1*3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-9a937b425243> in <module>
# ----> 1 S1*3
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %%
for i in S1:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
1 in S1
# Out:
# True

# %%
# Functions
len(S1)
# Out:
# 5

# %%
min(S1)
# Out:
# 1

# %%
max(S1)
# Out:
# 5

# %%
sorted(S1)
# Out:
# [1, 2, 3, 4, 5]

# %%
sorted(S1, reverse = True)
# Out:
# [5, 4, 3, 2, 1]

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
S2
# Out:
# {3, 4, 5, 6, 7}

# %%
S1.union(S2)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
S1.intersection(S2)
# Out:
# {3, 4, 5}

# %%
S1.difference(S2)
# Out:
# {1, 2}

# %%
S2.difference(S1)
# Out:
# {6, 7}

# %%
S1.symmetric_difference(S2) # item jo ek dusre mei available nahi hai
# Out:
# {1, 2, 6, 7}

# %%
S1.isdisjoint(S2)
# Out:
# False

# %%
S1.issubset(S2)
# Out:
# False

# %%
S1.issuperset(S2)
# Out:
# False

# %%
S1.clear()
S1
# Out:
# set()
