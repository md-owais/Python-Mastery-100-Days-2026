# %%
class Phone:
    def __init__(self,price,brand,camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera
        
#     def buy(self):
#         print("Buying a phone")
        
#     def return_phone(self):
#         print("Returning a phone")
        
class SmartPhone(Phone):
    pass

s= SmartPhone(20000,"Apple", 13)
# Out:
# Inside phone constructor

# %%
print(s.brand)
# Out:
# Apple

# %%
class Phone:
    def __init__(self,price,brand,camera):
        print("Inside phone constructor")
        self.price = price
        self.__brand = brand # brand private data member
        self.camera = camera
        
#     def buy(self):
#         print("Buying a phone")
        
#     def return_phone(self):
#         print("Returning a phone")
        
class SmartPhone(Phone):
    pass

s= SmartPhone(20000,"Apple", 13)
print(s.__brand)
# Out:
# Inside phone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-d826fbfc0947> in <module>
#      16
#      17 s= SmartPhone(20000,"Apple", 13)
# ---> 18 print(s.__brand)
#
# AttributeError: 'SmartPhone' object has no attribute '__brand'
