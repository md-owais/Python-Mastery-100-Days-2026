# %% [raw]
# Strings are sequence of characters
# In Python specially, strings are a sequence of Unicode Charactes
# 1. Creating Strings
# 2. Accessing Stings
# 3. Adding Chars to Strings
# 4. Editing Strings
# 5. Deleting Stings
# 6. Operations of Strings
# 7. String Functions

# %%
# creating
c = 'Hello'
print(c)
# Out:
# Hello

# %%
c = "Hello"
print(c)
# Out:
# Hello

# %%
# 'It's raining outside' - It will throw an error
"It's raining outside"
# Out:
# "It's raining outside"

# %%
c = '''Hello'''
print(c)
# Multi line strings
# Out:
# Hello

# %%
c = """Hello"""
print(c)
# Out:
# Hello

# %%
c = str("Hello")
c
# Out:
# 'Hello'
