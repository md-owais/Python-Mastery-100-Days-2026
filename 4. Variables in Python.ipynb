# %%
# Variable - are containers for future use
Name = 'Owais'

# %%
print(Name)
# Out:
# Owais

# %%
# No variable declaration in Python

# %%
# Dynamic Typing - creating varilable such away that it understand that which Data type of values gona be stored
# Static Typing - need to specify data type value

# %%
print(Name)
# Out:
# Owais

# %%
Name = 4
print(Name)
# Out:
# 4

# %%
Name = True
print(Name)
# Out:
# True

# %%
# Dynamic Binding - When one variable can able to store multiple data types

# %%
# special syntax
a = 5; b = 6; c = 7
print(a)
print(b)
print(c)
# Out:
# 5
# 6
# 7

# %%
a, b, c = 4, 5, 6
print(a)
print(b)
print(c)
# Out:
# 4
# 5
# 6

# %%
a = b = c = 6
print(a)
print(b)
print(c)
# Out:
# 6
# 6
# 6
