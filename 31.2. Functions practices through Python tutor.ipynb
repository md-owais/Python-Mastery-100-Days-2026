# %%
def func_a():
    print('inside func_a')

def func_b(y):
    print('inside func_b')
    return y

def func_c(z):
    print('inside func_c')
    return z()

print(func_a())
print(5 + func_b(2))
print(func_c(func_a))
# Out:
# inside func_a
# None
# inside func_b
# 7
# inside func_c
# inside func_a
# None

# %%
def f(y):
    x = 1
    x += 1
    print(x)
x = 5
f(x)
print(x)
# Out:
# 2
# 5

# %%
def g(y):
    print(x)
    print(x+1)
x = 5
g(x)
print(x)
# Out:
# 5
# 6
# 5

# %%
def h(y):
    x += 1 # leads to an error without line 'global x' inside h
x = 5 
h(x)
print(x)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-3-6ef847d617b9> in <module>
#       2     x += 1 # leads to an error without line 'global x' inside h
#       3 x = 5
# ----> 4 h(x)
#       5 print(x)
#
# <ipython-input-3-6ef847d617b9> in h(y)
#       1 def h(y):
# ----> 2     x += 1 # leads to an error without line 'global x' inside h
#       3 x = 5
#       4 h(x)
#       5 print(x)
#
# UnboundLocalError: local variable 'x' referenced before assignment

# %%
def h(y):
    global x # In case there is no any options then only will use global
    x += 1 # leads to an error without line 'global x' inside h
x = 5 
h(x)
print(x)
# Out:
# 6

# %%
def f(x):
    x = x + 1
    print('in f(x): x=', x)
    return x
x = 3
z = f(x)
print('in main program scope:z=', z)
print('in main program scope:x=', x)
# Out:
# in f(x): x= 4
# in main program scope:z= 4
# in main program scope:x= 3

# %%
# nested functions
def f():
    print('Inside f')
    def g():
        print('Inside g')
    g()
f()
# Out:
# Inside f
# Inside g

# %%
def f():
    print('Inside f')
    def g():
        print('Inside g')
    g()
g()

# Nested function main program se hidden rahta hai
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-7dcea3178b4b> in <module>
#       4         print('Inside g')
#       5     g()
# ----> 6 g()
#
# TypeError: g() missing 1 required positional argument: 'y'

# %%
def g(x):
    def h():
        x = 'abc'
    x = x + 1
    print('in g(x):x=', x)
    h()
    return x
x = 3
z = g(x)
# Out:
# in g(x):x= 4

# %%
def g(x):
    def h(x):
        x = x + 1
        print('in h(x):x=', x)
    x = x + 1
    print('in g(x):x=', x)
    h(x)
    return x
x = 3
z = g(x)
print('in main program scope:x=',x)
print('in main program scope:z=',z)
# Out:
# in g(x):x= 4
# in h(x):x= 5
# in main program scope:x= 3
# in main program scope:z= 4

# %%
# Everything in Python is an object and functions too

# %%
# Functions as objects
def f(num):
    return num**2
f(2)
# Out:
# 4

# %%
f(4)
# Out:
# 16

# %%
x = f
x(2)
# Out:
# 4

# %%
x(4)
# Out:
# 16

# %%
del f # we can delete functions in Python

# %%
f(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c510dc86724b> in <module>
# ----> 1 f(2)
#
# NameError: name 'f' is not defined

# %%
type(x)
# Out:
# function

# %%
L = [1,2,3,4]
L
# Out:
# [1, 2, 3, 4]

# %%
L = [1,2,3,4,x]
L
# Out:
# [1, 2, 3, 4, <function __main__.f(num)>]

# %%
L[-1](3)
# Out:
# 9

# %%
L = [1,2,3,4,x(5)]
L
# Out:
# [1, 2, 3, 4, 25]

# %% [markdown]
# # So what?
# 1. Renaming a function
# 2. Deleting a function
# 3. Storing a function
# 4. returning a function
# 5. Function as argument

# %%
def func_a():
    print('inside func_a')

def func_c(z):
    print('inside func_c')
    return z()

print(func_c(func_a))
# Out:
# inside func_c
# inside func_a
# None

# %%
def f():
    def x(a, b):
        return a+b
    return x
# the first part, f(), returns a function object
# then apply that function with parameters 3 and 4
val = f()(3,4)
print(val)
# Out:
# 7

# %% [markdown]
# # Benefits of using a function
# 1. Every code is self-contained and used to break up the entire login into pieces(Code Modularity)
# 2. Works on the philosophy of write once use forever!(Code Reusability)
# 3. Code is organized and coherent(Code Redability)
