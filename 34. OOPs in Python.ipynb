# %%
# OOP - it's different style of writing of code
L = [1,2,3,4]
L
# Out:
# [1, 2, 3, 4]

# %%
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-23af83e72fe0> in <module>
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
city = 'Kolkata'
city.append('a')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-e6919d38d70d> in <module>
#       1 city = 'Kolkata'
# ----> 2 city.append('a')
#
# AttributeError: 'str' object has no attribute 'append'

# %%
a = 3
a.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-0e4e9266bba5> in <module>
#       1 a = 3
# ----> 2 a.upper()
#
# AttributeError: 'int' object has no attribute 'upper'

# %% [raw]
# Generality to Specificity
#
# OOP Concepts:
# Class: Class is a blueprint
# Object
# Polymorphism
# Encapsulation
# Inheritance
# Abstraction

# %%
a = 2
print(type(a))
# Out:
# <class 'int'>

# %%
L
# Out:
# [1, 2, 3, 4]

# %% [raw]
# Class has two things - Data or property and Functions or Behavior

# %%
# Class Basic Structure
class Car:
    color = "blue" #data
    model = "sports" #data
    def calculate_avg_speed(km,time): #snake case
        #Some code
        pass

# %%
# Class name should be in Pascal case
ThisIsPascalCase
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-93d2cd5c0164> in <module>
#       1 # Class name should be in Pascal case
# ----> 2 ThisIsPascalCase
#
# NameError: name 'ThisIsPascalCase' is not defined

# %%
thisIsPascalCase
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-12f1c0e4f051> in <module>
# ----> 1 thisIsPascalCase
#
# NameError: name 'thisIsPascalCase' is not defined

# %%
# Car - _color, _milage, _engine - Private
# +car-avg_speed, +open_airbag - public
