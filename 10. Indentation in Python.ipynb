# %%
name = 'Alam'
if name == 'Owais':
    print('line1') # space is called as Indentation - we use tab also to give the indentation
    print('line2')
else:
    print('line3')
# Out:
# line3

# %%
name = 'Alam'
if name == 'Owais':
print('line1') # space is called as Indentation - we use tab also to give the indentation
    print('line2')
else:
    print('line3')
# Out:
#   File "<ipython-input-4-6a9730311c1e>", line 3
#     print('line1') # space is called as Indentation - we use tab also to give the indentation
#     ^
# IndentationError: expected an indented block

# %%
name = 'Owais'
if name == 'Owais':
    print('line1') # Auto space is called as Indentation - we use tab also to give the indentation
    print('line2') # Dont't use spaces and always use tab
    if 5 == 5:
        print('line4')
else:
    print('line3')
# Out:
# line1
# line2
# line4
