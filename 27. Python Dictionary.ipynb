# %%
{"Name":"Owais", "Gender":"Male"}
# Out:
# {'Name': 'Owais', 'Gender': 'Male'}

# %%
# Rule1 : Dictionary has no indexing
# Rule2: Dictionary is a mutable types
# Rule 3: Keys -> immutable, values -> they can be mutable
# Rule 4: Keys should be unique

# Mutable -> List/Sets/dictionary
# Immutable -> Strings/tuples/int/float/boolean/complex

# %%
# create
D = {}
D
# Out:
# {}

# %%
D = {"Name":"Owais", "Gender":"Male"}
D
# Out:
# {'Name': 'Owais', 'Gender': 'Male'}

# %%
D1 = {[1,2,3]:"Owais"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-6fae793edcac> in <module>
# ----> 1 D1 = {[1,2,3]:"Owais"}
#
# TypeError: unhashable type: 'list'

# %%
D1 = {(1,2,3):"Owais"}
D1
# Out:
# {(1, 2, 3): 'Owais'}

# %%
D2 = {"Name":"Rahul","Name":"Rohit"}
D2
# Out:
# {'Name': 'Rohit'}

# %%
D3 = {"Name":"Rohit", "College":"HIT","Marks":{"M1":50,"DS":54,"Eng":67}}
D3
# Out:
# {'Name': 'Rohit', 'College': 'HIT', 'Marks': {'M1': 50, 'DS': 54, 'Eng': 67}}

# %%
# Accesss
D1
# Out:
# {(1, 2, 3): 'Owais'}

# %%
D[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-a2635327f65d> in <module>
# ----> 1 D[0]
#
# KeyError: 0

# %%
D['Name']
# Out:
# 'Owais'

# %%
D['Gender']
# Out:
# 'Male'

# %%
D
# Out:
# {'Name': 'Owais', 'Gender': 'Male'}

# %%
D3
# Out:
# {'Name': 'Rohit', 'College': 'HIT', 'Marks': {'M1': 50, 'DS': 54, 'Eng': 67}}

# %%
D3["Marks"]
# Out:
# {'M1': 50, 'DS': 54, 'Eng': 67}

# %%
D3['Marks']['DS']
# Out:
# 54

# %%
# Edit
D
# Out:
# {'Name': 'Owais', 'Gender': 'Male'}

# %%
D['Nmae'] = 'Rahul'
D
# Out:
# {'Name': 'Owais', 'Gender': 'Male', 'Nmae': 'Rahul'}

# %%
D3['Marks']['DS'] = 64
D3
# Out:
# {'Name': 'Rohit', 'College': 'HIT', 'Marks': {'M1': 50, 'DS': 64, 'Eng': 67}}

# %%
D
# Out:
# {'Name': 'Owais', 'Gender': 'Male', 'Nmae': 'Rahul'}

# %%
D.get('Name') # In 2D won't work this function
D
# Out:
# {'Name': 'Owais', 'Gender': 'Male', 'Nmae': 'Rahul'}

# %%
# Add new key-value pair
D
# Out:
# {'Name': 'Owais', 'Gender': 'Male', 'Nmae': 'Rahul'}

# %%
D['Age'] = 23
D
# Out:
# {'Name': 'Owais', 'Gender': 'Male', 'Nmae': 'Rahul', 'Age': 23}

# %%
D3['Marks']['M2'] = 50
D3
# Out:
# {'Name': 'Rohit',
#  'College': 'HIT',
#  'Marks': {'M1': 50, 'DS': 64, 'Eng': 67, 'M2': 50}}

# %%
# delete
D5 = {}
D5
# Out:
# {}

# %%
del D5

# %%
D5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-84f0b423de29> in <module>
# ----> 1 D5
#
# NameError: name 'D5' is not defined

# %%
del D['Gender']

# %%
D
# Out:
# {'Name': 'Owais', 'Nmae': 'Rahul', 'Age': 23}

# %%
D.clear()
D
# Out:
# {}

# %%
# Operations
D1
# Out:
# {(1, 2, 3): 'Owais'}

# %%
D2
# Out:
# {'Name': 'Rohit'}

# %%
D1 + D2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-d732271f04a6> in <module>
# ----> 1 D1 + D2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
D3
# Out:
# {'Name': 'Rohit',
#  'College': 'HIT',
#  'Marks': {'M1': 50, 'DS': 64, 'Eng': 67, 'M2': 50}}

# %%
for i in D3:
    print(i)
# Out:
# Name
# College
# Marks

# %%
for i in D3:
    print(i, D3[i])
# Out:
# Name Rohit
# College HIT
# Marks {'M1': 50, 'DS': 64, 'Eng': 67, 'M2': 50}

# %%
"Rohit" in D3
# Out:
# False

# %%
"Name" in D3
# Out:
# True

# %%
len(D3)
# Out:
# 3

# %%
min(D3)
# Out:
# 'College'

# %%
max(D3)
# Out:
# 'Name'

# %%
sorted(D3)
# Out:
# ['College', 'Marks', 'Name']

# %%
sorted(D3, reverse = True)
# Out:
# ['Name', 'Marks', 'College']

# %%
D3.keys()
# Out:
# dict_keys(['Name', 'College', 'Marks'])

# %%
D3.values()
# Out:
# dict_values(['Rohit', 'HIT', {'M1': 50, 'DS': 64, 'Eng': 67, 'M2': 50}])
