# %%
# correct email - mdowais@gamil.com
# password - 1234
email = input("Enter your email: ")
password = input("Enter your password: ")
if email == 'mdowais@gamil.com' and password == '1234':
    print("Welcome")
else:
    print("Incorrect Credentials")
# Out:
# Enter your email: mdowais@gamil.com
# Enter your password: 1234
# Welcome

# %%
email = input("Enter your email: ")
password = input("Enter your password: ")
if email == 'mdowais@gamil.com' and password == '1234':
    print("Welcome")
elif email == 'mdowais@gamil.com' and password != '1234':
    print("Password Incorrect")
    password = input("Re-enter your password: ")
    if password == '1234': # Nested if-else
        print("Finally Correct")
    else:
        print("Still Incorrect")
else:
    print("Incorrect Credentials")
# Out:
# Enter your email: mdowais@gamil.com
# Enter your password: 123
# Password Incorrect
# Re-enter your password: 1234
# Finally Correct

# %%
# if @ is not available in an email then it's not valid email
email = input("Enter your email: ")

if '@' in email:
    password = input("Enter your password: ")
    if email == 'mdowais@gamil.com' and password == '1234':
        print("Welcome")
    elif email == 'mdowais@gamil.com' and password != '1234':
        print("Password Incorrect")
        password = input("Re-enter your password: ")
        if password == '1234': # Nested if-else
            print("Finally Correct")
        else:
            print("Still Incorrect")
    else:
        print("Incorrect Credentials")
else:
    print("Invalid Email")
# Out:
# Enter your email: owais12
# Invalid Email
