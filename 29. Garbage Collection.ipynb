# %%
# GC - periodically free up the memory if there is unnecessry data without reference variable

# %%
# Weird Behaviour -1
import sys
a = 2
b = a
c = b
sys.getrefcount(a) # very common no or system ke bahut saare variable use kar rahe hai
# Out:
# 1241

# %%
a = 61
b = a
c = b

# %%
sys.getrefcount(a)
# Out:
# 25

# %%
# Actual ansewer is 4
a = 717
b = a 
c = b

# %%
sys.getrefcount(a)
# Out:
# 4

# %%
# WB - 2
d = 717
d = c

# %%
sys.getrefcount(a)
# Out:
# 5

# %%
a = 4
b = 4
id(a)
# Out:
# 140712181573520

# %%
id(b)
# Out:
# 140712181573520

# %%
a = 257
b = 257

id(a)
# Out:
# 2644257048464

# %%
id(b)
# Out:
# 2644257048368

# %%
# -5 to 256 -> once increases or decreases then id is differring

# %%
# WB3
a = 'haldia'
b = 'haldia'
id(a)
# Out:
# 2644257904688

# %%
id(b)
# Out:
# 2644257904688

# %%
a = 'haldia inst tech'
b = 'haldia inst tech'
id(a)
# Out:
# 2644257887696

# %%
id(b)
# Out:
# 2644257890016

# %%
a = 'haldia_inst_tech'
b = 'haldia_inst_tech'
id(a)
# Out:
# 2644257927296

# %%
id(b)
# Out:
# 2644257927296

# %% [raw]
# Python's Weird Behaviour
# 1. getrefcount anomaly
# 2. -5 to 256
# 3. Strings

# %%
L = [1,2,3]
id(L)
# Out:
# 2644256896896

# %%
id(L[0])
# Out:
# 140712181573424

# %%
id(2)
# Out:
# 140712181573456

# %%
id(3)
# Out:
# 140712181573488

# %%
L[2] = 1
L
# Out:
# [1, 2, 1]

# %%
id(L[2])
# Out:
# 140712181573424

# %%
L = [1,2,3,[4,5]]
L
# Out:
# [1, 2, 3, [4, 5]]
